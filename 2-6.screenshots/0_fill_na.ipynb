# %%
import pandas as pd

# %%
df = pd.read_excel('labeled_data/0328-all_url_list.xlsx', index_col=0)
# rename columns
print(df.columns)
# df['comments'] = df['comments'].astype('string')
# df['category'] = df['category'].astype('string')
# df['url'] = df['url'].astype('string')
# df['ERROR'] = df['ERROR'].astype('Int64')
# df['usecase'] = df['usecase'].astype('Int64')
# df['interactions'] = df['interactions'].astype('Int64')
df = df.astype({
    'comments': 'string',
    'category': 'string',
    'url': 'string',
    'ERROR': 'Int64',
    'usecase': 'Int64',
    'interactions': 'Int64',
})
# Out:
# Index(['category', 'url', 'ERROR', 'usecase', 'interactions', 'comments'], dtype='object')

# %%
df.comments = df.comments.fillna('')
df
# Out:
#                         category                                        url  \
# index
# 0                  ['cssdesign']                 http://matchmaker.msi.com/
# 1                  ['cssdesign']  https://controltheweather.geostorm.movie/
# 2                   ['awwwards']          http://1000.chromeexperiments.com
# 3                     ['custom']     http://127.0.0.1:8000/test1/webgl/easy
# 4                     ['custom']     http://127.0.0.1:8000/test1/webgl/hard
# ...                          ...                                        ...
# 8612                ['awwwards']                 https://zulu.longines.com/
# 8613   ['awwwards', 'cssdesign']                    https://zumi.gucci.com/
# 8614                ['awwwards']                        https://zunc.studio
# 8615                ['awwwards']                         https://zuplo.com/
# 8616                  ['tranco']                     https://zylotrade.com/
#
#        ERROR  usecase  interactions comments
# index
# 0          1     <NA>             0
# 1          0     <NA>             0
# 2          0     <NA>             1
# 3          0        1             0
# 4          0        1             0
# ...      ...      ...           ...      ...
# 8612    <NA>        1             1
# 8613    <NA>        1             1
# 8614    <NA>        3             0
# 8615    <NA>        3             0
# 8616    <NA>        1             0
#
# [8617 rows x 6 columns]

# %%
loc_error_na = (df['comments'].isna() & df['ERROR'].isna())
df.loc[loc_error_na, 'ERROR'] = 0

# %%
loc_usecase_na = (df['ERROR'] == 0) & df['usecase'].isna()
df.loc[loc_usecase_na, 'usecase'] = 1

# %%
loc_usecase_3_na = (df['ERROR'] == 0) & (df['usecase'] == 3) & df['interactions'].isna()
df.loc[loc_usecase_3_na, 'interactions'] = 0

# %%
loc_error = (df['ERROR'] != 0) & (~df['usecase'].isna() | ~df['interactions'].isna())
df[loc_error]
# Out:
#             category                                                url  \
# index
# 0      ['cssdesign']                         http://matchmaker.msi.com/
# 287     ['awwwards']                          http://dim-sum.resn.co.nz
# 1002   ['cssdesign']  http://uniel.jp/https://nojdigmedmer.tele2.se/en/
# 1119    ['awwwards']                              http://www.apexvj.com
# 1127    ['awwwards']                           http://www.audir8.com.au
# 1152    ['awwwards']                        http://www.brakebillsu.com/
# 1534    ['awwwards']                       http://www.siemens.com/santa
# 8520   ['cssdesign']                      https://www.zodiac-hustle.com
# 8521    ['awwwards']                     https://www.zodiac-hustle.com/
# 8545    ['awwwards']                        https://yandex.com/everest/
# 8546    ['awwwards']                         https://yanlinma.com/ninx/
#
#        ERROR  usecase  interactions   comments
# index
# 0          1     <NA>             0
# 287        1     <NA>             0
# 1002       1     <NA>             0  URL error
# 1119       3     <NA>             0
# 1127       3     <NA>             0
# 1152       1     <NA>             0
# 1534       1     <NA>             0     scroll
# 8520       1        3          <NA>
# 8521       1        3          <NA>
# 8545       1        3             0        404
# 8546       1        3             0        404

# %%
df.loc[loc_error, 'interactions'] = None
df.loc[loc_error, 'usecase'] = None

# %%
loc_url_error = df.url.str[7:].str.contains('://')
tmp = df[loc_url_error]
tmp
# Out:
#             category                                                url  \
# index
# 21     ['cssdesign']  http://2018.makemepulse.comhttp://www.honigstu...
# 108    ['cssdesign']  http://astateofwar.org.au/http://www.imjp.co.j...
# 117    ['cssdesign']          http://authentiks.fr/http://taotajima.jp/
# 125    ['cssdesign']  http://awards.paris/new-micra-experiencehttps:...
# 151    ['cssdesign']  http://blackrainbow.la/http://astoryabouttrust...
# ...              ...                                                ...
# 8384   ['cssdesign']  https://www.vitamincornwall.com/sproutbreakout...
# 8445   ['cssdesign']     https://www.wibicom.be/https://www.itssharl.ee
# 8553   ['cssdesign']      https://yetimotion.comhttps://david-hckh.com/
# 8608   ['cssdesign']           https://zoccon.me/https://tagree.agency/
# 8610   ['cssdesign']  https://zonanorte.27films.fr/https://www.daily...
#
#        ERROR  usecase  interactions comments
# index
# 21         1     <NA>          <NA>
# 108        1     <NA>          <NA>
# 117        0        3             0
# 125        1     <NA>          <NA>
# 151        1     <NA>          <NA>
# ...      ...      ...           ...      ...
# 8384       1     <NA>          <NA>
# 8445       0        1             1
# 8553       1     <NA>          <NA>       白屏
# 8608       1     <NA>          <NA>   url不太对
# 8610       1     <NA>          <NA>      404
#
# [89 rows x 6 columns]

# %%
df.loc[loc_url_error, 'ERROR'] = 1
df.loc[loc_url_error, 'usecase'] = None
df.loc[loc_url_error, 'interactions'] = None
df.loc[loc_url_error, 'comments'] = 'URL error'

# %%
df.loc[df.comments == 'File not found', 'ERROR'] = 1
df.loc[df.comments == '白屏', 'comments'] = 'white'

# %%
df.to_pickle('output/0328-all_url_list.pkl')
df.to_excel('output/0328-all_url_list.xlsx')

# %%
df.dtypes
# Out:
# category        string
# url             string
# ERROR            Int64
# usecase          Int64
# interactions     Int64
# comments        string
# dtype: object
