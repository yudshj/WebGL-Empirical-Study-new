# %%
import pandas as pd

# %%
df = pd.read_excel('labeled_data/0328-all_url_list.xlsx', index_col=0)
df['comments'] = df['comments'].astype('string')
df['category'] = df['category'].astype('string')
df['url'] = df['url'].astype('string')
df['ERROR'] = df['ERROR'].astype('Int64')
df['usecase'] = df['usecase'].astype('Int64')
df['interactions'] = df['interactions'].astype('Int64')

# %%
df
# Out:
#                         category                                        url  \
# index
# 0                  ['cssdesign']                 http://matchmaker.msi.com/
# 1                  ['cssdesign']  https://controltheweather.geostorm.movie/
# 2                   ['awwwards']          http://1000.chromeexperiments.com
# 3                     ['custom']     http://127.0.0.1:8000/test1/webgl/easy
# 4                     ['custom']     http://127.0.0.1:8000/test1/webgl/hard
# ...                          ...                                        ...
# 8612                ['awwwards']                 https://zulu.longines.com/
# 8613   ['awwwards', 'cssdesign']                    https://zumi.gucci.com/
# 8614                ['awwwards']                        https://zunc.studio
# 8615                ['awwwards']                         https://zuplo.com/
# 8616                  ['tranco']                     https://zylotrade.com/
#
#        ERROR  usecase  interactions comments
# index
# 0          1     <NA>             0     <NA>
# 1          0     <NA>             0     <NA>
# 2          0     <NA>             1     <NA>
# 3          0        1             0     <NA>
# 4          0        1             0     <NA>
# ...      ...      ...           ...      ...
# 8612    <NA>        1             1     <NA>
# 8613    <NA>        1             1     <NA>
# 8614    <NA>        3             0     <NA>
# 8615    <NA>        3             0     <NA>
# 8616    <NA>        1             0     <NA>
#
# [8617 rows x 6 columns]

# %%
loc_error_na = (df['comments'].isna() & df['ERROR'].isna())
df.loc[loc_error_na, 'ERROR'] = 0

# %%
loc_usecase_na = (df['ERROR'] == 0) & df['usecase'].isna()
df.loc[loc_usecase_na, 'usecase'] = 1

# %%
loc_usecase_3_na = (df['ERROR'] == 0) & (df['usecase'] == 3) & df['interactions'].isna()
df.loc[loc_usecase_3_na, 'interactions'] = 0

# %%
loc_error = (df['ERROR'] != 0) & (~df['usecase'].isna() | ~df['interactions'].isna() | ~df['comments'].isna())
df[loc_error]
# Out:
#                         category  \
# index
# 0                  ['cssdesign']
# 218                 ['awwwards']
# 287                 ['awwwards']
# 291                ['cssdesign']
# 1002               ['cssdesign']
# 1119                ['awwwards']
# 1127                ['awwwards']
# 1152                ['awwwards']
# 1534                ['awwwards']
# 4302               ['cssdesign']
# 4304                ['awwwards']
# 4307                ['awwwards']
# 4353                ['awwwards']
# 4361                ['awwwards']
# 4368                ['awwwards']
# 4390   ['awwwards', 'cssdesign']
# 4475                ['awwwards']
# 8520               ['cssdesign']
# 8521                ['awwwards']
# 8545                ['awwwards']
# 8546                ['awwwards']
# 8553               ['cssdesign']
# 8574                ['awwwards']
# 8608               ['cssdesign']
# 8610               ['cssdesign']
#
#                                                      url  ERROR  usecase  \
# index
# 0                             http://matchmaker.msi.com/      1     <NA>
# 218                               http://cityofdrones.io      1     <NA>
# 287                            http://dim-sum.resn.co.nz      1     <NA>
# 291                           https://www.marine-i.co.uk      1     <NA>
# 1002   http://uniel.jp/https://nojdigmedmer.tele2.se/en/      1     <NA>
# 1119                               http://www.apexvj.com      3     <NA>
# 1127                            http://www.audir8.com.au      3     <NA>
# 1152                         http://www.brakebillsu.com/      1     <NA>
# 1534                        http://www.siemens.com/santa      1     <NA>
# 4302                            https://museum.xbox.com/      1     <NA>
# 4304                         https://music.airfrance.com      1     <NA>
# 4307                           https://mvp.cybertribe.io      1     <NA>
# 4353                               https://navigator.com      1     <NA>
# 4361          https://neuro-symbolic-lab.com/experience/      1     <NA>
# 4368               https://new.spaceapegames.com/careers      1     <NA>
# 4390                 https://nextlevelunique.com/studio/      1     <NA>
# 4475                                https://oceandev.io/      1     <NA>
# 8520                       https://www.zodiac-hustle.com      1        3
# 8521                      https://www.zodiac-hustle.com/      1        3
# 8545                         https://yandex.com/everest/      1        3
# 8546                          https://yanlinma.com/ninx/      1        3
# 8553       https://yetimotion.comhttps://david-hckh.com/      1     <NA>
# 8574                        https://z-ar-experience.com/      1     <NA>
# 8608            https://zoccon.me/https://tagree.agency/      1     <NA>
# 8610   https://zonanorte.27films.fr/https://www.daily...      1     <NA>
#
#        interactions   comments
# index
# 0                 0       <NA>
# 218            <NA>     ubuntu
# 287               0       <NA>
# 291            <NA>  URL error
# 1002              0  URL error
# 1119              0       <NA>
# 1127              0       <NA>
# 1152              0       <NA>
# 1534              0     scroll
# 4302           <NA>      white
# 4304           <NA>      white
# 4307           <NA>      white
# 4353           <NA>      white
# 4361           <NA>      white
# 4368           <NA>      white
# 4390           <NA>      white
# 4475           <NA>        404
# 8520           <NA>       <NA>
# 8521           <NA>       <NA>
# 8545              0        404
# 8546              0        404
# 8553           <NA>         白屏
# 8574           <NA>         白屏
# 8608           <NA>     url不太对
# 8610           <NA>        404

# %%
df.loc[loc_error, 'interactions'] = None
df.loc[loc_error, 'usecase'] = None

# %%
loc_url_error = df.url.str[4:].str.contains('http://')
tmp = df[loc_url_error]
tmp
# Out:
#             category                                                url  \
# index
# 21     ['cssdesign']  http://2018.makemepulse.comhttp://www.honigstu...
# 108    ['cssdesign']  http://astateofwar.org.au/http://www.imjp.co.j...
# 117    ['cssdesign']          http://authentiks.fr/http://taotajima.jp/
# 151    ['cssdesign']  http://blackrainbow.la/http://astoryabouttrust...
# 210    ['cssdesign']  http://chordsurfer.redbull.com/http://corrupte...
# 566    ['cssdesign']    http://lgbt.allstateonline.com/http://nclud.com
# 638    ['cssdesign']  http://mono.acervo.iohttp://scars.forhonorgame...
# 721    ['cssdesign']  http://operationsamusreturns.comhttp://en.ugle...
# 883    ['cssdesign']    http://sound-of-change.com/http://honda-dct.com
# 988    ['cssdesign']  http://tzina.space/http://opencontinents.com/?...
# 1145   ['cssdesign']  http://www.blancpain-ocean-commitment.comhttp:...
# 1252   ['cssdesign']  http://www.espn.com/espn/feature/story/_/id/19...
# 1266   ['cssdesign']  http://www.fetedeslumieres.lyon.fr/animationht...
# 1496   ['cssdesign']  http://www.rdigroup.ru/en/http://tomerlerner.com/
# 1516   ['cssdesign']  http://www.russellandcodrinks.com/http://www.t...
# 1592   ['cssdesign']  http://www.timeshift165.comhttp://www.makersha...
# 1612   ['cssdesign']  http://www.univet.ithttp://showyourwarrior.won...
# 1646   ['cssdesign']  http://www.weareuprising.com/http://www.magicl...
# 3523   ['cssdesign']  https://hpsnz.org.nzhttp://www.machupicchu360v...
# 4666   ['cssdesign']               https://pf2018.o2.cz/enhttp://uix.me
# 4961   ['cssdesign']  https://routefifty.caffeina.com/http://www.sak...
# 5011   ['cssdesign']  https://sakumastudio.com/http://loveforiceland...
# 5134   ['cssdesign']  https://showcase.withgoogle.com/healthcare-sec...
# 5455   ['cssdesign']  https://thelivingexperience.eu.panasonic.com/h...
# 6242   ['cssdesign']  https://www.brontidebg.comhttp://mainframe.agv...
# 6760   ['cssdesign']  https://www.fotospatzek.athttp://goggles.wedze...
#
#        ERROR  usecase  interactions comments
# index
# 21         1     <NA>          <NA>     <NA>
# 108        1     <NA>          <NA>     <NA>
# 117        0        3             0     <NA>
# 151        1     <NA>          <NA>     <NA>
# 210        1     <NA>          <NA>     <NA>
# 566        1     <NA>          <NA>     <NA>
# 638        1     <NA>          <NA>     <NA>
# 721        1     <NA>          <NA>     <NA>
# 883     <NA>        3             0   domain
# 988        1     <NA>          <NA>     <NA>
# 1145       1     <NA>          <NA>     <NA>
# 1252       0        1             1     <NA>
# 1266       0        3             0     <NA>
# 1496       1     <NA>          <NA>     <NA>
# 1516       0        1             0     <NA>
# 1592       1     <NA>          <NA>     <NA>
# 1612       1     <NA>          <NA>     <NA>
# 1646       0        1             0   scroll
# 3523       1     <NA>          <NA>     <NA>
# 4666       1     <NA>          <NA>     <NA>
# 4961       1     <NA>          <NA>     <NA>
# 5011       0        1             0     <NA>
# 5134       0        1             0     <NA>
# 5455       0        3             0     <NA>
# 6242       1     <NA>          <NA>     <NA>
# 6760       1     <NA>          <NA>     <NA>

# %%
df.loc[loc_url_error, 'ERROR'] = 1
df.loc[loc_url_error, 'usecase'] = None
df.loc[loc_url_error, 'interactions'] = None
df.loc[loc_url_error, 'comments'] = 'URL error'

# %%
df.loc[df.comments == 'File not found', 'ERROR'] = 1
df.loc[df.comments == '白屏', 'comments'] = 'white'

# %%
df.to_pickle('output/0328-all_url_list.pkl')
df.to_excel('output/0328-all_url_list.xlsx')

# %%
df.dtypes
# Out:
# category        string
# url             string
# ERROR            Int64
# usecase          Int64
# interactions     Int64
# comments        string
# dtype: object
