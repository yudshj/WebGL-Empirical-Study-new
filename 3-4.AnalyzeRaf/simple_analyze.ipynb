# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_context("paper", font_scale=2)
sns.set_style("whitegrid")

# %%
df = pd.read_pickle('imr/0504-df_simple.pkl.zst', compression='zstd')

# %%
df.columns.tolist()
# Out:
# ['idx-frame',
#  'idx',
#  'url',
#  'date',
#  'netIdleTimeout',
#  'frame.name',
#  'frame.url',
#  'frame.error',
#  'frame.data.url',
#  'frame.data.title',
#  'frame.data.accessTime',
#  'frame.data.usedOffScreenCanvas',
#  'frame.data.when',
#  'frame.data.whenUsedWebgl',
#  'frame.data.contextInfo.canvasSize',
#  'frame.data.contextInfo.canvasHidden',
#  'frame.data.contextInfo.canvasContained',
#  'frame.data.contextInfo.memoryInfo.memory.texture',
#  'frame.data.contextInfo.memoryInfo.memory.buffer',
#  'frame.data.contextInfo.memoryInfo.memory.renderbuffer',
#  'frame.data.contextInfo.memoryInfo.memory.drawingbuffer',
#  'frame.data.contextInfo.memoryInfo.memory.total',
#  'frame.data.contextInfo.memoryInfo.resources.buffer',
#  'frame.data.contextInfo.memoryInfo.resources.framebuffer',
#  'frame.data.contextInfo.memoryInfo.resources.renderbuffer',
#  'frame.data.contextInfo.memoryInfo.resources.program',
#  'frame.data.contextInfo.memoryInfo.resources.query',
#  'frame.data.contextInfo.memoryInfo.resources.shader',
#  'frame.data.contextInfo.memoryInfo.resources.sampler',
#  'frame.data.contextInfo.memoryInfo.resources.texture',
#  'frame.data.contextInfo.memoryInfo.resources.transformFeedback',
#  'frame.data.contextInfo.memoryInfo.resources.vertexArray',
#  'frame.data.contextInfo.memoryInfo.resources.sync',
#  'frame.data.contextInfo.maghsk.createTime',
#  'frame.data.contextInfo.maghsk.createArguments.0',
#  'frame.data.contextInfo.maghsk.createArguments.1.alpha',
#  'frame.data.contextInfo.maghsk.createArguments.1.depth',
#  'frame.data.contextInfo.maghsk.createArguments.1.stencil',
#  'frame.data.contextInfo.maghsk.createArguments.1.antialias',
#  'frame.data.contextInfo.maghsk.createArguments.1.premultipliedAlpha',
#  'frame.data.contextInfo.maghsk.createArguments.1.preserveDrawingBuffer',
#  'frame.data.contextInfo.maghsk.createArguments.1.powerPreference',
#  'frame.data.contextInfo.maghsk.createArguments.1.failIfMajorPerformanceCaveat',
#  'frame.data.contextInfo.contextAttributes.alpha',
#  'frame.data.contextInfo.contextAttributes.antialias',
#  'frame.data.contextInfo.contextAttributes.depth',
#  'frame.data.contextInfo.contextAttributes.desynchronized',
#  'frame.data.contextInfo.contextAttributes.failIfMajorPerformanceCaveat',
#  'frame.data.contextInfo.contextAttributes.powerPreference',
#  'frame.data.contextInfo.contextAttributes.premultipliedAlpha',
#  'frame.data.contextInfo.contextAttributes.preserveDrawingBuffer',
#  'frame.data.contextInfo.contextAttributes.stencil',
#  'frame.data.contextInfo.contextAttributes.xrCompatible',
#  'frame.data.contextInfo.contextAttributes',
#  'frame.data.contextInfo.maghsk.createArguments.1.preferLowPowerToHighPerformance',
#  'frame.data.contextInfo.maghsk.createArguments.1.majorVersion',
#  'frame.data.contextInfo.maghsk.createArguments.1.minorVersion',
#  'frame.data.contextInfo.maghsk.createArguments.1.explicitSwapControl',
#  'frame.data.contextInfo.maghsk.createArguments.1.proxyContextToMainThread',
#  'frame.data.contextInfo.maghsk.createArguments.1.renderViaOffscreenBackBuffer',
#  'frame.data.contextInfo.maghsk.createArguments.1.xrCompatible',
#  'frame.data.contextInfo.maghsk.createArguments.1.enableExtensionsByDefault',
#  'frame.data.contextInfo.maghsk.createArguments.1.audioEngine',
#  'frame.data.contextInfo.maghsk.createArguments.1.desynchronized',
#  'frame.data.contextInfo.maghsk.createArguments.1.disableWebGL2Support',
#  'frame.data.contextInfo.maghsk.createArguments.1.deterministicLockstep',
#  'frame.data.contextInfo.maghsk.createArguments.1.lockstepMaxSteps',
#  'frame.data.contextInfo.maghsk.createArguments.1.timeStep',
#  'frame.data.contextInfo.maghsk.createArguments.1.autoClear',
#  'frame.data.contextInfo.maghsk.createArguments.1.extensions',
#  'frame.data.contextInfo.maghsk.createArguments.1.shaderSources',
#  'frame.data.contextInfo.maghsk.createArguments.1.fullscreen',
#  'frame.data.contextInfo.maghsk.createArguments.1.enableFrustumCulling',
#  'frame.data.contextInfo.maghsk.createArguments.1.scrollwheel',
#  'frame.data.contextInfo.maghsk.createArguments.1.shaderStats',
#  'frame.data.contextInfo.maghsk.createArguments.1.stats',
#  'frame.data.contextInfo.maghsk.createArguments.1.annotation_cycle',
#  'frame.data.contextInfo.maghsk.createArguments.1.anialias',
#  'frame.data.contextInfo.maghsk.createArguments.1',
#  'frame.data.contextInfo.maghsk.createArguments.1.canvas',
#  'frame.data.contextInfo.maghsk.createArguments.1.autospin',
#  'frame.data.contextInfo.maghsk.createArguments.1.autostart',
#  'frame.data.contextInfo.maghsk.createArguments.1.internal',
#  'frame.data.contextInfo.maghsk.createArguments.1.max_texture_size',
#  'frame.data.contextInfo.maghsk.createArguments.1.orbit_constraint_pan',
#  'frame.data.contextInfo.maghsk.createArguments.1.orbit_constraint_zoom_in',
#  'frame.data.contextInfo.maghsk.createArguments.1.orbit_constraint_zoom_out',
#  'frame.data.contextInfo.maghsk.createArguments.1.preload',
#  'frame.data.contextInfo.maghsk.createArguments.1.transparent',
#  'frame.data.contextInfo.maghsk.createArguments.1.ui_ar',
#  'frame.data.contextInfo.maghsk.createArguments.1.ui_color',
#  'frame.data.contextInfo.maghsk.createArguments.1.ui_fullscreen',
#  'frame.data.contextInfo.maghsk.createArguments.1.ui_theme',
#  'frame.data.contextInfo.maghsk.createArguments.1.maxDevicePixelRatio',
#  'frame.data.contextInfo.maghsk.createArguments.1.InputSources.Mouse.scrollwheel',
#  'frame.data.contextInfo.maghsk.createArguments.1.InputSources.Keyboard.sourceElement',
#  'frame.data.contextInfo.maghsk.createArguments.1.InputSources.WebVR.pollInterval',
#  'frame.data.contextInfo.maghsk.createArguments.1.InputSources.GamePad.enable',
#  'frame.data.contextInfo.maghsk.createArguments.1.failIfMajorPerformanceCaviet',
#  'frame.data.contextInfo.maghsk.createArguments.1.preferWebGl2',
#  'frame.data.contextInfo.maghsk.createArguments.1.perPixelLighting',
#  'frame.data.contextInfo.maghsk.createArguments.1.ignoreWebgl2',
#  'frame.data.contextInfo.maghsk.createArguments.1.width',
#  'frame.data.contextInfo.maghsk.createArguments.1.height',
#  'frame.data.contextInfo.maghsk.createArguments.1.doNotHandleTouchAction',
#  'frame.data.contextInfo.maghsk.createArguments.1.doNotHandleContextLost',
#  'frame.data.contextInfo.maghsk.createArguments.1.logarithmicDepthBuffer',
#  'frame.data.contextInfo.maghsk.createArguments.1.0',
#  'frame.data.contextInfo.maghsk.createArguments.1.api_version',
#  'frame.data.contextInfo.maghsk.createArguments.1.api_id',
#  'frame.data.contextInfo.maghsk.createArguments.1.useHighPrecisionFloats',
#  'frame.data.contextInfo.maghsk.createArguments.1.useHighPrecisionMatrix',
#  'frame.data.contextInfo.maghsk.createArguments.1.force_webgl2',
#  'frame.data.contextInfo.maghsk.createArguments.1.xr_enabled',
#  'frame.data.contextInfo.maghsk.createArguments.1.webgl2',
#  'frame.data.contextInfo.maghsk.createArguments.1.webgl1',
#  'frame.data.contextInfo.maghsk.createArguments.1.throwOnError',
#  'frame.data.contextInfo.maghsk.createArguments.1.manageState',
#  'frame.data.contextInfo.maghsk.createArguments.1.debug',
#  'frame.data.contextInfo.maghsk.createArguments.1.derivative',
#  'frame.data.contextInfo.maghsk.createArguments.1.limitDeviceRatio',
#  'frame.data.contextInfo.maghsk.createArguments.1.autoEnableWebVR',
#  'frame.data.contextInfo.maghsk.createArguments.1.annotations_visible',
#  'frame.data.contextInfo.maghsk.createArguments.1.willReadFrequently',
#  'frame.data.contextInfo.maghsk.createArguments.1.qf',
#  'frame.data.contextInfo.maghsk.createArguments.1.oj',
#  'frame.data.contextInfo.maghsk.createArguments.1.Jf',
#  'frame.data.contextInfo.maghsk.createArguments.1.qg',
#  'frame.data.contextInfo.maghsk.createArguments.1.sj',
#  'frame.data.contextInfo.maghsk.createArguments.1.vj',
#  'frame.data.contextInfo.maghsk.createArguments.1.forceSRGBBufferSupportState',
#  'frame.data.contextInfo.maghsk.createArguments.1.device_pixel_ratio',
#  'frame.data.contextInfo.maghsk.createArguments.1.stencilBuffer',
#  'frame.data.contextInfo.maghsk.createArguments.1.referrer',
#  'frame.data.contextInfo.maghsk.createArguments.1.useWebgl2',
#  'frame.data.contextInfo.maghsk.createArguments.1.dpi',
#  'frame.data.contextInfo.maghsk.createArguments.1.adaptToDeviceRatio',
#  'frame.data.contextInfo.maghsk.createArguments.1.dnt']

# %%
df_simple = df[['idx','frame.data.contextInfo.memoryInfo.memory.texture',
 'frame.data.contextInfo.memoryInfo.memory.buffer',
 'frame.data.contextInfo.memoryInfo.memory.renderbuffer',
 'frame.data.contextInfo.memoryInfo.memory.drawingbuffer',
 'frame.data.contextInfo.memoryInfo.memory.total',
 'frame.data.contextInfo.memoryInfo.resources.buffer',
 'frame.data.contextInfo.memoryInfo.resources.framebuffer',
 'frame.data.contextInfo.memoryInfo.resources.renderbuffer',
 'frame.data.contextInfo.memoryInfo.resources.program',
 'frame.data.contextInfo.memoryInfo.resources.query',
 'frame.data.contextInfo.memoryInfo.resources.shader',
 'frame.data.contextInfo.memoryInfo.resources.sampler',
 'frame.data.contextInfo.memoryInfo.resources.texture',
 'frame.data.contextInfo.memoryInfo.resources.transformFeedback',
 'frame.data.contextInfo.memoryInfo.resources.vertexArray',
 'frame.data.contextInfo.memoryInfo.resources.sync',]].dropna()

# %%
df_simple.drop(columns='idx').describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
#        frame.data.contextInfo.memoryInfo.memory.texture
# count                                      6.122000e+03  \
# mean                                       3.427420e+07
# std                                        8.572208e+07
# min                                        0.000000e+00
# 25%                                        0.000000e+00
# 50%                                        1.932000e+03
# 75%                                        2.951834e+07
# 90%                                        1.079153e+08
# 95%                                        1.574286e+08
# 99%                                        4.328099e+08
# max                                        1.362082e+09
#
#        frame.data.contextInfo.memoryInfo.memory.buffer
# count                                     6.122000e+03  \
# mean                                      1.753401e+06
# std                                       7.813138e+06
# min                                       0.000000e+00
# 25%                                       0.000000e+00
# 50%                                       1.400000e+02
# 75%                                       3.358610e+05
# 90%                                       3.521460e+06
# 95%                                       9.044008e+06
# 99%                                       3.089500e+07
# max                                       1.982624e+08
#
#        frame.data.contextInfo.memoryInfo.memory.renderbuffer
# count                                       6.122000e+03      \
# mean                                        2.181455e+06
# std                                         1.324934e+07
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# 90%                                         3.686400e+06
# 95%                                         8.388608e+06
# 99%                                         4.404019e+07
# max                                         4.329266e+08
#
#        frame.data.contextInfo.memoryInfo.memory.drawingbuffer
# count                                       6.122000e+03       \
# mean                                        9.455752e+06
# std                                         1.134494e+07
# min                                         0.000000e+00
# 25%                                         1.080000e+06
# 50%                                         7.223040e+06
# 75%                                         1.310640e+07
# 90%                                         2.211840e+07
# 95%                                         2.211840e+07
# 99%                                         4.423680e+07
# max                                         2.116734e+08
#
#        frame.data.contextInfo.memoryInfo.memory.total
# count                                    6.122000e+03  \
# mean                                     4.766480e+07
# std                                      9.604252e+07
# min                                      0.000000e+00
# 25%                                      1.080000e+06
# 50%                                      1.393446e+07
# 75%                                      4.887856e+07
# 90%                                      1.268055e+08
# 95%                                      1.990713e+08
# 99%                                      4.622958e+08
# max                                      1.426039e+09
#
#        frame.data.contextInfo.memoryInfo.resources.buffer
# count                                        6122.000000   \
# mean                                          107.333388
# std                                           688.408789
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             2.000000
# 75%                                            17.000000
# 90%                                           159.000000
# 95%                                           478.000000
# 99%                                          1819.370000
# max                                         26546.000000
#
#        frame.data.contextInfo.memoryInfo.resources.framebuffer
# count                                        6122.000000        \
# mean                                            1.877981
# std                                            12.712200
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# 90%                                             4.000000
# 95%                                             8.000000
# 99%                                            22.000000
# max                                           684.000000
#
#        frame.data.contextInfo.memoryInfo.resources.renderbuffer
# count                                        6122.000000         \
# mean                                            0.942502
# std                                             6.923199
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# 90%                                             2.000000
# 95%                                             4.000000
# 99%                                            15.000000
# max                                           456.000000
#
#        frame.data.contextInfo.memoryInfo.resources.program
# count                                        6122.000000    \
# mean                                            3.898399
# std                                            10.468184
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             3.000000
# 90%                                            12.000000
# 95%                                            18.000000
# 99%                                            38.000000
# max                                           234.000000
#
#        frame.data.contextInfo.memoryInfo.resources.query
# count                                             6122.0  \
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# 90%                                                  0.0
# 95%                                                  0.0
# 99%                                                  0.0
# max                                                  0.0
#
#        frame.data.contextInfo.memoryInfo.resources.shader
# count                                        6122.000000   \
# mean                                            1.854949
# std                                            10.042706
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# 90%                                             1.000000
# 95%                                            10.000000
# 99%                                            36.000000
# max                                           296.000000
#
#        frame.data.contextInfo.memoryInfo.resources.sampler
# count                                        6122.000000    \
# mean                                            0.024012
# std                                             0.650923
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# 90%                                             0.000000
# 95%                                             0.000000
# 99%                                             0.000000
# max                                            18.000000
#
#        frame.data.contextInfo.memoryInfo.resources.texture
# count                                        6122.000000    \
# mean                                           16.961287
# std                                            79.846487
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             3.000000
# 75%                                             7.000000
# 90%                                            31.000000
# 95%                                            59.000000
# 99%                                           288.000000
# max                                          2089.000000
#
#        frame.data.contextInfo.memoryInfo.resources.transformFeedback
# count                                        6122.000000              \
# mean                                            0.000327
# std                                             0.018073
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# 90%                                             0.000000
# 95%                                             0.000000
# 99%                                             0.000000
# max                                             1.000000
#
#        frame.data.contextInfo.memoryInfo.resources.vertexArray
# count                                        6122.000000        \
# mean                                           23.343842
# std                                           176.788162
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             3.000000
# 90%                                            32.000000
# 95%                                            87.950000
# 99%                                           432.110000
# max                                          8816.000000
#
#        frame.data.contextInfo.memoryInfo.resources.sync
# count                                       6122.000000
# mean                                           0.174453
# std                                            3.071114
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# 90%                                            0.000000
# 95%                                            0.000000
# 99%                                            3.000000
# max                                          214.000000

# %%
df_simple.drop(columns='idx').describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])[[x for x in df_simple.columns if x.startswith('frame.data.contextInfo.memoryInfo.resources.')]]
# Out:
#        frame.data.contextInfo.memoryInfo.resources.buffer
# count                                        6122.000000   \
# mean                                          107.333388
# std                                           688.408789
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             2.000000
# 75%                                            17.000000
# 90%                                           159.000000
# 95%                                           478.000000
# 99%                                          1819.370000
# max                                         26546.000000
#
#        frame.data.contextInfo.memoryInfo.resources.framebuffer
# count                                        6122.000000        \
# mean                                            1.877981
# std                                            12.712200
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# 90%                                             4.000000
# 95%                                             8.000000
# 99%                                            22.000000
# max                                           684.000000
#
#        frame.data.contextInfo.memoryInfo.resources.renderbuffer
# count                                        6122.000000         \
# mean                                            0.942502
# std                                             6.923199
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# 90%                                             2.000000
# 95%                                             4.000000
# 99%                                            15.000000
# max                                           456.000000
#
#        frame.data.contextInfo.memoryInfo.resources.program
# count                                        6122.000000    \
# mean                                            3.898399
# std                                            10.468184
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             3.000000
# 90%                                            12.000000
# 95%                                            18.000000
# 99%                                            38.000000
# max                                           234.000000
#
#        frame.data.contextInfo.memoryInfo.resources.query
# count                                             6122.0  \
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# 90%                                                  0.0
# 95%                                                  0.0
# 99%                                                  0.0
# max                                                  0.0
#
#        frame.data.contextInfo.memoryInfo.resources.shader
# count                                        6122.000000   \
# mean                                            1.854949
# std                                            10.042706
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# 90%                                             1.000000
# 95%                                            10.000000
# 99%                                            36.000000
# max                                           296.000000
#
#        frame.data.contextInfo.memoryInfo.resources.sampler
# count                                        6122.000000    \
# mean                                            0.024012
# std                                             0.650923
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# 90%                                             0.000000
# 95%                                             0.000000
# 99%                                             0.000000
# max                                            18.000000
#
#        frame.data.contextInfo.memoryInfo.resources.texture
# count                                        6122.000000    \
# mean                                           16.961287
# std                                            79.846487
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             3.000000
# 75%                                             7.000000
# 90%                                            31.000000
# 95%                                            59.000000
# 99%                                           288.000000
# max                                          2089.000000
#
#        frame.data.contextInfo.memoryInfo.resources.transformFeedback
# count                                        6122.000000              \
# mean                                            0.000327
# std                                             0.018073
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# 90%                                             0.000000
# 95%                                             0.000000
# 99%                                             0.000000
# max                                             1.000000
#
#        frame.data.contextInfo.memoryInfo.resources.vertexArray
# count                                        6122.000000        \
# mean                                           23.343842
# std                                           176.788162
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             3.000000
# 90%                                            32.000000
# 95%                                            87.950000
# 99%                                           432.110000
# max                                          8816.000000
#
#        frame.data.contextInfo.memoryInfo.resources.sync
# count                                       6122.000000
# mean                                           0.174453
# std                                            3.071114
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# 90%                                            0.000000
# 95%                                            0.000000
# 99%                                            3.000000
# max                                          214.000000

# %%
tmp = df_simple[[
    'frame.data.contextInfo.memoryInfo.resources.framebuffer',
    'frame.data.contextInfo.memoryInfo.resources.renderbuffer',
    'frame.data.contextInfo.memoryInfo.resources.program',
    'frame.data.contextInfo.memoryInfo.resources.query',
    'frame.data.contextInfo.memoryInfo.resources.shader',
    'frame.data.contextInfo.memoryInfo.resources.sampler',
    'frame.data.contextInfo.memoryInfo.resources.texture',
    'frame.data.contextInfo.memoryInfo.resources.transformFeedback',
    'frame.data.contextInfo.memoryInfo.resources.vertexArray',
    'frame.data.contextInfo.memoryInfo.resources.sync'
]]

sns.displot(tmp / tmp.max(axis=0), kind='kde', height=5, aspect=2)
plt.xlim(0, 0.1)
# Out:
# (0.0, 0.1)

# %%
tmp = df_simple[[
    'frame.data.contextInfo.memoryInfo.memory.texture',
    'frame.data.contextInfo.memoryInfo.memory.buffer',
    'frame.data.contextInfo.memoryInfo.memory.renderbuffer',
    'frame.data.contextInfo.memoryInfo.memory.drawingbuffer',
    'frame.data.contextInfo.memoryInfo.memory.total',
 ]]

sns.displot(tmp / tmp.max(axis=0), kind='kde', height=5, aspect=2)
plt.xlim(0, 0.15)
# Out:
# (0.0, 0.15)

# %%
to_plot = [
    # 'frame.data.contextInfo.memoryInfo.resources.framebuffer',
    # 'frame.data.contextInfo.memoryInfo.resources.renderbuffer',
    'frame.data.contextInfo.memoryInfo.resources.program',
    'frame.data.contextInfo.memoryInfo.resources.shader',
    # 'frame.data.contextInfo.memoryInfo.resources.sampler',
    'frame.data.contextInfo.memoryInfo.resources.texture',
    # 'frame.data.contextInfo.memoryInfo.resources.transformFeedback',
    'frame.data.contextInfo.memoryInfo.resources.vertexArray',
]

# %%
tmp = df_simple[to_plot].rename(columns={
    'frame.data.contextInfo.memoryInfo.resources.program': 'Program',
    'frame.data.contextInfo.memoryInfo.resources.shader': 'Shader',
    'frame.data.contextInfo.memoryInfo.resources.texture': 'Texture',
    'frame.data.contextInfo.memoryInfo.resources.vertexArray': 'Vertex Array',
})
tmp = tmp[tmp.sum(axis=1) > 0]

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 3))
for i, ax in enumerate(axes.flatten()):
    # sns.histplot(tmp.iloc[:, i][tmp.iloc[:, i] > 0], ax=ax, bins=20)
    taa = tmp.iloc[:, i]
    sns.histplot(taa[(taa > 0) & (taa < taa.quantile(0.99))], ax=ax, bins=50)
    # sns.scatterplot(x=taa.index, y=taa.values, ax=ax)
    # sns.boxplot(x=tmp.iloc[:, i], ax=ax)
    # ax.set_xscale('log')
    # ax.set_yscale('log')
    ax.set_ylabel('')
    # y scientific notation
    ax.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
    ax.set_title(tmp.columns[i])
axes[0].set_ylabel('Count')
plt.savefig('fig/results_context_resources.pdf', bbox_inches='tight')

# %%
tmp.describe()
# Out:
#            Program       Shader      Texture  Vertex Array
# count  4200.000000  4200.000000  4200.000000   4200.000000
# mean      5.682381     2.703810    24.723095     34.026429
# std      12.231204    12.030163    95.403078    212.594294
# min       0.000000     0.000000     0.000000      0.000000
# 25%       1.000000     0.000000     2.000000      0.000000
# 50%       2.000000     0.000000     4.000000      1.000000
# 75%       6.000000     0.000000    14.000000     11.000000
# max     234.000000   296.000000  2089.000000   8816.000000

# %% [markdown]
# ## noraf

# %%
# df_frame = pd.read_pickle('imr/0501-df_frame-raf.pkl.zst', compression='zstd')
# df_context = pd.read_pickle('imr/0501-df_context.pkl.zst', compression='zstd')
df_context_noraf = pd.read_pickle('imr/0504-df_context-noraf.pkl.zst', compression='zstd')
df_context_noraf = df_context_noraf[df_context_noraf['label_ERROR'].isna() | (df_context_noraf['label_ERROR'] == 0)]
# df_shader = pd.read_pickle('imr/0501-df_shader-noraf.pkl.zst', compression='zstd')

# %%
df_context_noraf.columns.tolist()
# Out:
# ['idx-frame',
#  'idx',
#  'category',
#  'label_ERROR',
#  'label_usecase',
#  'label_interactions',
#  'label_comments',
#  'url',
#  'date',
#  'netIdleTimeout',
#  'raf_path',
#  'frame.url',
#  'frame.title',
#  'frame.date',
#  'frame.when',
#  'frame.counter.frames',
#  'frame.counter.contextsNum',
#  'frame.counter.usedWebGL',
#  'frame.counter.usedOffScreenCanvas',
#  'frame.context.canvasSize',
#  'frame.context.canvasHidden',
#  'frame.context.canvasContained',
#  'frame.context.maghsk.createTime',
#  'frame.context.maghsk.createArguments.0',
#  'frame.context.maghsk.createArguments.1.alpha',
#  'frame.context.maghsk.createArguments.1.depth',
#  'frame.context.maghsk.createArguments.1.stencil',
#  'frame.context.maghsk.createArguments.1.antialias',
#  'frame.context.maghsk.createArguments.1.premultipliedAlpha',
#  'frame.context.maghsk.createArguments.1.preserveDrawingBuffer',
#  'frame.context.maghsk.createArguments.1.powerPreference',
#  'frame.context.maghsk.createArguments.1.failIfMajorPerformanceCaveat',
#  'frame.context.maghsk.counter.funcCount.getShaderPrecisionFormat',
#  'frame.context.maghsk.counter.funcCount.getParameter',
#  'frame.context.maghsk.counter.funcCount.getExtension',
#  'frame.context.maghsk.counter.funcCount.createTexture',
#  'frame.context.maghsk.counter.funcCount.bindTexture',
#  'frame.context.maghsk.counter.funcCount.texParameteri',
#  'frame.context.maghsk.counter.funcCount.texImage2D',
#  'frame.context.maghsk.counter.funcCount.texImage3D',
#  'frame.context.maghsk.counter.funcCount.clearColor',
#  'frame.context.maghsk.counter.funcCount.clearDepth',
#  'frame.context.maghsk.counter.funcCount.clearStencil',
#  'frame.context.maghsk.counter.funcCount.enable',
#  'frame.context.maghsk.counter.funcCount.depthFunc',
#  'frame.context.maghsk.counter.funcCount.frontFace',
#  'frame.context.maghsk.counter.funcCount.cullFace',
#  'frame.context.maghsk.counter.funcCount.getContextAttributes',
#  'frame.context.maghsk.counter.funcCount.viewport',
#  'frame.context.maghsk.counter.funcCount.createBuffer',
#  'frame.context.maghsk.counter.funcCount.bindBuffer',
#  'frame.context.maghsk.counter.funcCount.bufferData',
#  'frame.context.maghsk.counter.funcCount.clear',
#  'frame.context.maghsk.counter.funcCount.createProgram',
#  'frame.context.maghsk.counter.funcCount.createShader',
#  'frame.context.maghsk.counter.funcCount.shaderSource',
#  'frame.context.maghsk.counter.funcCount.compileShader',
#  'frame.context.maghsk.counter.funcCount.attachShader',
#  'frame.context.maghsk.counter.funcCount.linkProgram',
#  'frame.context.maghsk.counter.funcCount.getProgramInfoLog',
#  'frame.context.maghsk.counter.funcCount.getShaderInfoLog',
#  'frame.context.maghsk.counter.funcCount.getProgramParameter',
#  'frame.context.maghsk.counter.funcCount.deleteShader',
#  'frame.context.maghsk.counter.funcCount.getActiveUniform',
#  'frame.context.maghsk.counter.funcCount.getUniformLocation',
#  'frame.context.maghsk.counter.funcCount.useProgram',
#  'frame.context.maghsk.counter.funcCount.uniformMatrix4fv',
#  'frame.context.maghsk.counter.funcCount.uniform1i',
#  'frame.context.maghsk.counter.funcCount.uniform3f',
#  'frame.context.maghsk.counter.funcCount.uniform1f',
#  'frame.context.maghsk.counter.funcCount.uniform3fv',
#  'frame.context.maghsk.counter.funcCount.uniformMatrix3fv',
#  'frame.context.maghsk.counter.funcCount.depthMask',
#  'frame.context.maghsk.counter.funcCount.colorMask',
#  'frame.context.maghsk.counter.funcCount.disable',
#  'frame.context.maghsk.counter.funcCount.createVertexArray',
#  'frame.context.maghsk.counter.funcCount.bindVertexArray',
#  'frame.context.maghsk.counter.funcCount.getActiveAttrib',
#  'frame.context.maghsk.counter.funcCount.getAttribLocation',
#  'frame.context.maghsk.counter.funcCount.enableVertexAttribArray',
#  'frame.context.maghsk.counter.funcCount.vertexAttribPointer',
#  'frame.context.maghsk.counter.funcCount.drawArrays',
#  'frame.context.maghsk.counter.bufferDataSent',
#  'frame.context.maghsk.counter.bufferSubDataSent',
#  'frame.context.maghsk.counter.vertexCount',
#  'frame.context.maghsk.counter.semanticVertexCount.0',
#  'frame.context.maghsk.counter.semanticVertexCount.1',
#  'frame.context.maghsk.counter.semanticVertexCount.2',
#  'frame.context.maghsk.counter.semanticVertexCount.3',
#  'frame.context.maghsk.counter.semanticVertexCount.4',
#  'frame.context.maghsk.counter.semanticVertexCount.5',
#  'frame.context.maghsk.counter.semanticVertexCount.6',
#  'frame.context.maghsk.counter.semanticVertexCalled.0',
#  'frame.context.maghsk.counter.semanticVertexCalled.1',
#  'frame.context.maghsk.counter.semanticVertexCalled.2',
#  'frame.context.maghsk.counter.semanticVertexCalled.3',
#  'frame.context.maghsk.counter.semanticVertexCalled.4',
#  'frame.context.maghsk.counter.semanticVertexCalled.5',
#  'frame.context.maghsk.counter.semanticVertexCalled.6',
#  'frame.context.maghsk.counter.texturePixelsSent',
#  'frame.context.maghsk.counter.textureTypes.Uint8Array',
#  'frame.context.maghsk.counter.textureBytesSent',
#  'frame.context.maghsk.extensions',
#  'frame.context.maghsk.programs',
#  'frame.context.maghsk.shaders',
#  'frame.context.contextAttributes.alpha',
#  'frame.context.contextAttributes.antialias',
#  'frame.context.contextAttributes.depth',
#  'frame.context.contextAttributes.desynchronized',
#  'frame.context.contextAttributes.failIfMajorPerformanceCaveat',
#  'frame.context.contextAttributes.powerPreference',
#  'frame.context.contextAttributes.premultipliedAlpha',
#  'frame.context.contextAttributes.preserveDrawingBuffer',
#  'frame.context.contextAttributes.stencil',
#  'frame.context.contextAttributes.xrCompatible',
#  'frame.context.contextAttributes',
#  'frame.context.maghsk.counter.funcCount.isContextLost',
#  'frame.context.maghsk.counter.funcCount.getShaderParameter',
#  'frame.context.maghsk.counter.funcCount.deleteProgram',
#  'frame.context.maghsk.counter.funcCount.blendFunc',
#  'frame.context.maghsk.counter.funcCount.pixelStorei',
#  'frame.context.maghsk.counter.funcCount.blendEquationSeparate',
#  'frame.context.maghsk.counter.funcCount.activeTexture',
#  'frame.context.maghsk.counter.funcCount.bindFramebuffer',
#  'frame.context.maghsk.counter.funcCount.flush',
#  'frame.context.maghsk.counter.funcCount.bindAttribLocation',
#  'frame.context.maghsk.counter.funcCount.uniform4f',
#  'frame.context.maghsk.counter.funcCount.uniform1iv',
#  'frame.context.maghsk.counter.funcCount.generateMipmap',
#  'frame.context.maghsk.counter.funcCount.drawElements',
#  'frame.context.maghsk.counter.funcCount.bufferSubData',
#  'frame.context.maghsk.counter.funcCount.createFramebuffer',
#  'frame.context.maghsk.counter.funcCount.framebufferTexture2D',
#  'frame.context.maghsk.counter.funcCount.uniform2f',
#  'frame.context.maghsk.counter.textureTypes.HTMLImageElement',
#  'frame.context.maghsk.counter.textureTypes.HTMLCanvasElement',
#  'frame.context.maghsk.counter.funcCount.scissor',
#  'frame.context.maghsk.counter.funcCount.getInternalformatParameter',
#  'frame.context.maghsk.counter.funcCount.uniformMatrix2fv',
#  'frame.context.maghsk.createArguments.1.preferLowPowerToHighPerformance',
#  'frame.context.maghsk.createArguments.1.majorVersion',
#  'frame.context.maghsk.createArguments.1.minorVersion',
#  'frame.context.maghsk.createArguments.1.explicitSwapControl',
#  'frame.context.maghsk.createArguments.1.proxyContextToMainThread',
#  'frame.context.maghsk.createArguments.1.renderViaOffscreenBackBuffer',
#  'frame.context.maghsk.counter.funcCount.getSupportedExtensions',
#  'frame.context.maghsk.counter.funcCount.blendFuncSeparate',
#  'frame.context.maghsk.counter.funcCount.stencilFuncSeparate',
#  'frame.context.maghsk.counter.funcCount.stencilOpSeparate',
#  'frame.context.maghsk.counter.funcCount.stencilMask',
#  'frame.context.maghsk.counter.funcCount.bindSampler',
#  'frame.context.maghsk.counter.funcCount.bindBufferBase',
#  'frame.context.maghsk.counter.funcCount.disableVertexAttribArray',
#  'frame.context.maghsk.counter.funcCount.texStorage2D',
#  'frame.context.maghsk.counter.funcCount.texSubImage2D',
#  'frame.context.maghsk.counter.funcCount.texStorage3D',
#  'frame.context.maghsk.counter.funcCount.texSubImage3D',
#  'frame.context.maghsk.counter.funcCount.compressedTexSubImage2D',
#  'frame.context.maghsk.counter.funcCount.uniformBlockBinding',
#  'frame.context.maghsk.counter.funcCount.getActiveUniformBlockName',
#  'frame.context.maghsk.counter.funcCount.getActiveUniformBlockParameter',
#  'frame.context.maghsk.counter.funcCount.getActiveUniforms',
#  'frame.context.maghsk.counter.funcCount.getUniformIndices',
#  'frame.context.maghsk.counter.funcCount.drawBuffers',
#  'frame.context.maghsk.counter.funcCount.invalidateFramebuffer',
#  'frame.context.maghsk.counter.funcCount.uniform4fv',
#  'frame.context.maghsk.counter.funcCount.uniform1fv',
#  'frame.context.maghsk.counter.funcCount.uniform2fv',
#  'frame.context.maghsk.counter.funcCount.fenceSync',
#  'frame.context.maghsk.counter.funcCount.clientWaitSync',
#  'frame.context.maghsk.counter.funcCount.deleteSync',
#  'frame.context.maghsk.counter.funcCount.deleteTexture',
#  'frame.context.maghsk.counter.funcCount.deleteBuffer',
#  'frame.context.maghsk.counter.semanticVertexCount.36064',
#  'frame.context.maghsk.counter.semanticVertexCalled.36064',
#  'frame.context.maghsk.counter.textureTypes.Uint16Array',
#  'frame.context.maghsk.counter.funcCount.bindRenderbuffer',
#  'frame.context.maghsk.counter.funcCount.blendEquation',
#  'frame.context.maghsk.counter.funcCount.createRenderbuffer',
#  'frame.context.maghsk.counter.funcCount.renderbufferStorage',
#  'frame.context.maghsk.counter.funcCount.framebufferRenderbuffer',
#  'frame.context.maghsk.counter.funcCount.checkFramebufferStatus',
#  'frame.context.maghsk.counter.funcCount.getError',
#  'frame.context.maghsk.counter.textureTypes.Float32Array',
#  'frame.context.maghsk.counter.funcCount.compressedTexImage2D',
#  'frame.context.maghsk.counter.funcCount.deleteFramebuffer',
#  'frame.context.maghsk.counter.funcCount.depthRange',
#  'frame.context.maghsk.counter.funcCount.vertexAttribDivisor',
#  'frame.context.maghsk.counter.funcCount.drawElementsInstanced',
#  'frame.context.maghsk.counter.funcCount.lineWidth',
#  'frame.context.maghsk.counter.funcCount.deleteVertexArray',
#  'frame.context.maghsk.counter.funcCount.deleteRenderbuffer',
#  'frame.context.maghsk.counter.semanticVertexCount.1029',
#  'frame.context.maghsk.counter.semanticVertexCalled.1029',
#  'frame.context.maghsk.counter.textureTypes.ImageBitmap',
#  'frame.context.maghsk.counter.funcCount.readPixels',
#  'frame.context.maghsk.pixelsRead',
#  'frame.context.maghsk.counter.funcCount.blendColor',
#  'frame.context.maghsk.counter.funcCount.hint',
#  'frame.context.maghsk.createArguments.1.xrCompatible',
#  'frame.context.maghsk.counter.funcCount.texParameterf',
#  'frame.context.maghsk.counter.funcCount.vertexAttrib2fv',
#  'frame.context.maghsk.counter.funcCount.stencilFunc',
#  'frame.context.maghsk.counter.funcCount.stencilOp',
#  'frame.context.maghsk.counter.funcCount.getUniformBlockIndex',
#  'frame.context.maghsk.counter.textureTypes.OffscreenCanvas',
#  'frame.context.maghsk.counter.funcCount.polygonOffset',
#  'frame.context.maghsk.counter.funcCount.validateProgram',
#  'frame.context.maghsk.counter.textureTypes.HTMLVideoElement',
#  'frame.context.maghsk.counter.funcCount.isProgram',
#  'frame.context.maghsk.counter.funcCount.vertexAttrib3fv',
#  'frame.context.maghsk.counter.funcCount.copyTexImage2D',
#  'frame.context.maghsk.createArguments.1.enableExtensionsByDefault',
#  'frame.context.maghsk.counter.funcCount.bindBufferRange',
#  'frame.context.maghsk.counter.funcCount.vertexAttrib4f',
#  'frame.context.maghsk.createArguments.1.audioEngine',
#  'frame.context.maghsk.counter.funcCount.renderbufferStorageMultisample',
#  'frame.context.maghsk.counter.funcCount.blitFramebuffer',
#  'frame.context.maghsk.counter.funcCount.getRenderbufferParameter',
#  'frame.context.maghsk.createArguments.1.desynchronized',
#  'frame.context.maghsk.counter.funcCount.readBuffer',
#  'frame.context.maghsk.createArguments.1.disableWebGL2Support',
#  'frame.context.maghsk.createArguments.1.deterministicLockstep',
#  'frame.context.maghsk.createArguments.1.lockstepMaxSteps',
#  'frame.context.maghsk.createArguments.1.timeStep',
#  'frame.context.maghsk.counter.funcCount.getQuery',
#  'frame.context.maghsk.counter.funcCount.copyTexSubImage2D',
#  'frame.context.maghsk.createArguments.1.autoClear',
#  'frame.context.maghsk.counter.funcCount.clearBufferfv',
#  'frame.context.maghsk.counter.textureTypes.ImageData',
#  'frame.context.maghsk.createArguments.1.extensions',
#  'frame.context.maghsk.createArguments.1.shaderSources',
#  'frame.context.maghsk.counter.funcCount.drawArraysInstanced',
#  'frame.context.maghsk.counter.funcCount.detachShader',
#  'frame.context.maghsk.counter.funcCount.getBufferParameter',
#  'frame.context.maghsk.counter.funcCount.isTexture',
#  'frame.context.maghsk.counter.semanticVertexCount.36064,36065',
#  'frame.context.maghsk.counter.semanticVertexCalled.36064,36065',
#  'frame.context.maghsk.counter.semanticVertexCount.undefined',
#  'frame.context.maghsk.counter.semanticVertexCalled.undefined',
#  'frame.context.maghsk.counter.funcCount.finish',
#  'frame.context.maghsk.createArguments.1.fullscreen',
#  'frame.context.maghsk.createArguments.1.enableFrustumCulling',
#  'frame.context.maghsk.createArguments.1.scrollwheel',
#  'frame.context.maghsk.createArguments.1.shaderStats',
#  'frame.context.maghsk.createArguments.1.stats',
#  'frame.context.maghsk.createArguments.1.annotation_cycle',
#  'frame.context.maghsk.createArguments.1.anialias',
#  'frame.context.maghsk.createArguments.1',
#  'frame.context.maghsk.counter.funcCount.uniform4i',
#  'frame.context.maghsk.createArguments.1.canvas',
#  'frame.context.maghsk.counter.funcCount.sampleCoverage',
#  'frame.context.maghsk.createArguments.1.autospin',
#  'frame.context.maghsk.createArguments.1.autostart',
#  'frame.context.maghsk.createArguments.1.internal',
#  'frame.context.maghsk.createArguments.1.max_texture_size',
#  'frame.context.maghsk.createArguments.1.orbit_constraint_pan',
#  'frame.context.maghsk.createArguments.1.orbit_constraint_zoom_in',
#  'frame.context.maghsk.createArguments.1.orbit_constraint_zoom_out',
#  'frame.context.maghsk.createArguments.1.preload',
#  'frame.context.maghsk.createArguments.1.transparent',
#  'frame.context.maghsk.createArguments.1.ui_ar',
#  'frame.context.maghsk.createArguments.1.ui_color',
#  'frame.context.maghsk.createArguments.1.ui_fullscreen',
#  'frame.context.maghsk.createArguments.1.ui_theme',
#  'frame.context.maghsk.createArguments.1.maxDevicePixelRatio',
#  'frame.context.maghsk.createArguments.1.InputSources.Mouse.scrollwheel',
#  'frame.context.maghsk.createArguments.1.InputSources.Keyboard.sourceElement',
#  'frame.context.maghsk.createArguments.1.InputSources.WebVR.pollInterval',
#  'frame.context.maghsk.createArguments.1.InputSources.GamePad.enable',
#  'frame.context.maghsk.counter.funcCount.uniform4iv',
#  'frame.context.maghsk.counter.funcCount.isEnabled',
#  'frame.context.maghsk.counter.funcCount.uniform2i',
#  'frame.context.maghsk.createArguments.1.failIfMajorPerformanceCaviet',
#  'frame.context.maghsk.createArguments.1.preferWebGl2',
#  'frame.context.maghsk.counter.funcCount.uniform2iv',
#  'frame.context.maghsk.createArguments.1.perPixelLighting',
#  'frame.context.maghsk.createArguments.1.ignoreWebgl2',
#  'frame.context.maghsk.counter.funcCount.isShader',
#  'frame.context.maghsk.counter.funcCount.isBuffer',
#  'frame.context.maghsk.createArguments.1.width',
#  'frame.context.maghsk.createArguments.1.height',
#  'frame.context.maghsk.counter.funcCount.vertexAttribIPointer',
#  'frame.context.maghsk.counter.funcCount.getTexParameter',
#  'frame.context.maghsk.counter.funcCount.createQuery',
#  'frame.context.maghsk.counter.funcCount.beginQuery',
#  'frame.context.maghsk.counter.funcCount.endQuery',
#  'frame.context.maghsk.counter.funcCount.getQueryParameter',
#  'frame.context.maghsk.counter.funcCount.deleteQuery',
#  'frame.context.maghsk.createArguments.1.doNotHandleTouchAction',
#  'frame.context.maghsk.createArguments.1.doNotHandleContextLost',
#  'frame.context.maghsk.counter.funcCount.isFramebuffer',
#  'frame.context.maghsk.counter.textureTypes.Uint32Array',
#  'frame.context.maghsk.createArguments.1.logarithmicDepthBuffer',
#  'frame.context.maghsk.counter.funcCount.stencilMaskSeparate',
#  'frame.context.maghsk.counter.funcCount.createSampler',
#  'frame.context.maghsk.counter.funcCount.samplerParameteri',
#  'frame.context.maghsk.counter.funcCount.samplerParameterf',
#  'frame.context.maghsk.counter.textureTypes.VideoFrame',
#  'frame.context.maghsk.counter.textureTypes.CustomElementsV1',
#  'frame.context.maghsk.createArguments.1.0',
#  'frame.context.maghsk.createArguments.1.api_version',
#  'frame.context.maghsk.createArguments.1.api_id',
#  'frame.context.maghsk.createArguments.1.useHighPrecisionFloats',
#  'frame.context.maghsk.createArguments.1.useHighPrecisionMatrix',
#  'frame.context.maghsk.counter.funcCount.vertexAttrib1f',
#  'frame.context.maghsk.counter.semanticVertexCount.36064,0',
#  'frame.context.maghsk.counter.semanticVertexCalled.36064,0',
#  'frame.context.maghsk.counter.funcCount.uniform3i',
#  'frame.context.maghsk.counter.funcCount.getVertexAttrib',
#  'frame.context.maghsk.counter.funcCount.getUniform',
#  'frame.context.maghsk.counter.semanticVertexCount.36064,36065,36066,36067',
#  'frame.context.maghsk.counter.semanticVertexCalled.36064,36065,36066,36067',
#  'frame.context.maghsk.createArguments.1.force_webgl2',
#  'frame.context.maghsk.createArguments.1.xr_enabled',
#  'frame.context.maghsk.counter.funcCount.createTransformFeedback',
#  'frame.context.maghsk.counter.funcCount.transformFeedbackVaryings',
#  'frame.context.maghsk.createArguments.1.webgl2',
#  'frame.context.maghsk.createArguments.1.webgl1',
#  'frame.context.maghsk.createArguments.1.throwOnError',
#  'frame.context.maghsk.createArguments.1.manageState',
#  'frame.context.maghsk.createArguments.1.debug',
#  'frame.context.maghsk.counter.funcCount.vertexAttrib1fv',
#  'frame.context.maghsk.counter.funcCount.vertexAttrib4fv',
#  'frame.context.maghsk.counter.textureTypes.e',
#  'frame.context.maghsk.createArguments.1.derivative',
#  'frame.context.maghsk.createArguments.1.limitDeviceRatio',
#  'frame.context.maghsk.createArguments.1.autoEnableWebVR',
#  'frame.context.maghsk.counter.textureTypes.Uint8ClampedArray',
#  'frame.context.maghsk.createArguments.1.annotations_visible',
#  'frame.context.maghsk.createArguments.1.willReadFrequently',
#  'frame.context.maghsk.counter.funcCount.bindTransformFeedback',
#  'frame.context.maghsk.counter.funcCount.beginTransformFeedback',
#  'frame.context.maghsk.counter.funcCount.endTransformFeedback',
#  'frame.context.maghsk.createArguments.1.qf',
#  'frame.context.maghsk.createArguments.1.oj',
#  'frame.context.maghsk.createArguments.1.Jf',
#  'frame.context.maghsk.createArguments.1.qg',
#  'frame.context.maghsk.createArguments.1.sj',
#  'frame.context.maghsk.createArguments.1.vj',
#  'frame.context.maghsk.counter.funcCount.framebufferTextureLayer',
#  'frame.context.maghsk.createArguments.1.forceSRGBBufferSupportState',
#  'frame.context.maghsk.counter.semanticVertexCount.',
#  'frame.context.maghsk.counter.semanticVertexCalled.',
#  'frame.context.maghsk.counter.textureTypes.Object',
#  'frame.context.maghsk.counter.funcCount.getShaderSource',
#  'frame.context.maghsk.counter.funcCount.uniform1uiv',
#  'frame.context.maghsk.createArguments.1.device_pixel_ratio',
#  'frame.context.maghsk.createArguments.1.stencilBuffer',
#  'frame.context.maghsk.counter.textureTypes.DataView',
#  'frame.context.maghsk.createArguments.1.referrer',
#  'frame.context.maghsk.createArguments.1.useWebgl2',
#  'frame.context.maghsk.counter.textureTypes.',
#  'frame.context.maghsk.createArguments.1.dpi',
#  'frame.context.maghsk.createArguments.1.clearColor',
#  'frame.context.maghsk.counter.funcCount.getAttachedShaders',
#  'frame.context.maghsk.createArguments.1.adaptToDeviceRatio',
#  'frame.context.maghsk.createArguments.1.dnt']

# %%
tmp = df_context_noraf[[
    'frame.context.maghsk.counter.funcCount.createTexture',
    # 'frame.context.maghsk.counter.funcCount.createBuffer',
    'frame.context.maghsk.counter.funcCount.createProgram',
    'frame.context.maghsk.counter.funcCount.createShader',
    'frame.context.maghsk.counter.funcCount.createVertexArray',
    # 'frame.context.maghsk.counter.funcCount.createFramebuffer',
    # 'frame.context.maghsk.counter.funcCount.createRenderbuffer',
    # 'frame.context.maghsk.counter.funcCount.createQuery',
    # 'frame.context.maghsk.counter.funcCount.createSampler',
    # 'frame.context.maghsk.counter.funcCount.createTransformFeedback',
]].rename(columns={
    'frame.context.maghsk.counter.funcCount.createTexture': 'Texture',
    # 'frame.context.maghsk.counter.funcCount.createBuffer': 'Buffer',
    'frame.context.maghsk.counter.funcCount.createProgram': 'Program',
    'frame.context.maghsk.counter.funcCount.createShader': 'Shader',
    'frame.context.maghsk.counter.funcCount.createVertexArray': 'Vertex Array',
    # 'frame.context.maghsk.counter.funcCount.createFramebuffer': 'Framebuffer',
    # 'frame.context.maghsk.counter.funcCount.createRenderbuffer': 'Renderbuffer',
    # 'frame.context.maghsk.counter.funcCount.createQuery': 'Query',
    # 'frame.context.maghsk.counter.funcCount.createSampler': 'Sampler',
    # 'frame.context.maghsk.counter.funcCount.createTransformFeedback': 'Transform Feedback',
})

# %%
tmp.describe()
# Out:
#             Texture       Program        Shader  Vertex Array
# count  12974.000000  12211.000000  12381.000000   3168.000000
# mean      22.564205      6.283351     12.120507     67.721591
# std       89.943251     13.871546     24.452529    539.308273
# min        1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      1.000000      2.000000      1.000000
# 50%        5.000000      3.000000      6.000000      3.000000
# 75%       16.000000      7.000000     15.000000     22.000000
# max     2690.000000    788.000000    912.000000  22046.000000

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 3))
for i, ax in enumerate(axes.flatten()):
    # sns.histplot(tmp.iloc[:, i][tmp.iloc[:, i] > 0], ax=ax, bins=20)
    taa = tmp.iloc[:, i]
    sns.histplot(taa[(taa > 0) & (taa < taa.quantile(0.99))], ax=ax, bins=50)
    # sns.scatterplot(x=taa.index, y=taa.values, ax=ax)
    # sns.boxplot(x=tmp.iloc[:, i], ax=ax)
    # ax.set_xscale('log')
    # ax.set_yscale('log')
    ax.set_ylabel('')
    # y scientific notation
    ax.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
    ax.set_title(tmp.columns[i])
axes[0].set_ylabel('Count')
plt.savefig('fig/results_context_resources.pdf', bbox_inches='tight')
